# %%
import numpy
import scipy.stats
m = 10
arr = numpy.array([7, 7, 1, 3, 2, 1, 5, 1, 4, 0, 2, 3, 3, 1, 2, 2, 3, 1, 4, 0, 8, 3, 5, 3, 0, 0, 7, 1, 1, 3, 1, 3, 2, 4, 1, 6, 2, 2, 4, 1, 3, 1, 1, 2, 7, 3, 3, 2, 2, 2])
numpy.random.seed(0)
π = numpy.array([0.5, 0.5])
μ = numpy.random.rand(2)
err = 1/99999999
i = 0
π_old = π
μ_old = μ
while (numpy.abs(π - π_old).sum() >= err) and (numpy.abs(μ - μ_old).sum() >= err) or (i == 0):
    print('{}:'.format(i), 'π = {}'.format(π), 'μ = {}'.format(μ))
    r = scipy.stats.binom.pmf(arr[:, None], m, μ[None, :]) * π[None, :]
    r = r/numpy.sum(r, axis=1)[:, None]
    π_old, μ_old = π.copy(), μ.copy()
    π = r.mean(axis=0)
    μ = numpy.sum(arr[:, None]*r, axis=0)/ (r.sum(axis=0)) /m
    i += 1
# Out:
# 0: π = [0.5 0.5] μ = [0.5488135  0.71518937]
# 1: π = [0.87073241 0.12926759] μ = [0.22956431 0.54237045]
# 2: π = [0.84523256 0.15476744] μ = [0.20708441 0.61360134]
# 3: π = [0.84234824 0.15765176] μ = [0.20280898 0.62900797]
# 4: π = [0.84360435 0.15639565] μ = [0.20269821 0.63302856]
# 5: π = [0.84483556 0.15516444] μ = [0.20295977 0.63501899]
# 6: π = [0.8457089 0.1542911] μ = [0.20317394 0.63629067]
# 7: π = [0.8463017 0.1536983] μ = [0.20332286 0.63714122]
# 8: π = [0.84670045 0.15329955] μ = [0.20342371 0.63771256]
# 9: π = [0.84696783 0.15303217] μ = [0.20349157 0.63809583]
# 10: π = [0.84714683 0.15285317] μ = [0.20353708 0.63835253]
# 11: π = [0.84726654 0.15273346] μ = [0.20356756 0.63852427]
# 12: π = [0.84734655 0.15265345] μ = [0.20358794 0.63863906]
# 13: π = [0.84739999 0.15260001] μ = [0.20360157 0.63871576]
# 14: π = [0.84743568 0.15256432] μ = [0.20361067 0.63876699]
# 15: π = [0.84745951 0.15254049] μ = [0.20361675 0.63880119]
# 16: π = [0.84747542 0.15252458] μ = [0.20362081 0.63882403]
# 17: π = [0.84748604 0.15251396] μ = [0.20362352 0.63883927]
# 18: π = [0.84749313 0.15250687] μ = [0.20362533 0.63884945]
# 19: π = [0.84749786 0.15250214] μ = [0.20362654 0.63885624]
# 20: π = [0.84750102 0.15249898] μ = [0.20362735 0.63886077]
# 21: π = [0.84750313 0.15249687] μ = [0.20362789 0.6388638 ]
# 22: π = [0.84750454 0.15249546] μ = [0.20362824 0.63886582]
# 23: π = [0.84750547 0.15249453] μ = [0.20362848 0.63886716]
# 24: π = [0.8475061 0.1524939] μ = [0.20362864 0.63886806]
# 25: π = [0.84750652 0.15249348] μ = [0.20362875 0.63886866]
# 26: π = [0.8475068 0.1524932] μ = [0.20362882 0.63886906]
# 27: π = [0.84750698 0.15249302] μ = [0.20362887 0.63886933]
# 28: π = [0.84750711 0.15249289] μ = [0.2036289  0.63886951]
# 29: π = [0.84750719 0.15249281] μ = [0.20362892 0.63886963]
# 30: π = [0.84750725 0.15249275] μ = [0.20362894 0.63886971]
# 31: π = [0.84750728 0.15249272] μ = [0.20362895 0.63886976]
# 32: π = [0.84750731 0.15249269] μ = [0.20362895 0.6388698 ]
# 33: π = [0.84750732 0.15249268] μ = [0.20362896 0.63886982]
# 34: π = [0.84750734 0.15249266] μ = [0.20362896 0.63886984]
# 35: π = [0.84750734 0.15249266] μ = [0.20362896 0.63886985]
